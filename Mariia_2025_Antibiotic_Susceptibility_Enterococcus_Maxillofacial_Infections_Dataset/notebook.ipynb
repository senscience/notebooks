# %% [markdown]
# # Antibiotic Susceptibility Pattern Exploration with `mlcroissant`
# This notebook provides a template for loading and exploring a dataset using the `mlcroissant` library.
#
# ### Dataset Source
# The dataset source is provided via a Croissant schema URL.

# %%
# Ensure `mlcroissant` library is installed
# !pip install mlcroissant

# %% [markdown]
# ## 1. Data Loading
# Load metadata and records from the dataset using `mlcroissant`.

# %%
import mlcroissant as mlc
import pandas as pd

# Define the dataset URL
url = 'https://sen.science/doi/10.71728/senscience.2ct8-xkdw/fair2.json'

# Load the dataset metadata
dataset = mlc.Dataset(url)
metadata = dataset.metadata
print(f"{metadata.get('name')}: {metadata.get('description')}")

# %% [markdown]
# ## 2. Data Overview
# Review available record sets, fields, and their IDs.

# %%
# Print all available record sets
record_sets = metadata.get('recordSet', [])
for record_set in record_sets:
    print(f"RecordSet: {record_set.get('@id')} - {record_set.get('name')}")

# %% [markdown]
# ## 3. Data Extraction
# Load data from a specific record set into a DataFrame for analysis. Use the record set and field `@id`s from the overview.

# %%
# Extract data from each record set
dataframes = {}

for record_set in record_sets:
    record_set_id = record_set.get('@id')
    records = list(dataset.records(record_set=record_set_id))
    dataframes[record_set_id] = pd.DataFrame(records)
    print(f"Columns in RecordSet {record_set_id}: {dataframes[record_set_id].columns.tolist()}")

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)
# Apply common data processing steps, such as filtering records based on specific criteria, normalizing numeric fields, and categorizing data. This section should include operations like removing outliers, transforming data distributions, or grouping data by key attributes to prepare it for further analysis.

# %%
# Select a numeric field for analysis
record_set_id = next(iter(dataframes))  # Choose the first available record set
df = dataframes[record_set_id]
numeric_field = 'field_id_for_numeric_analysis'  # Example: Replace with actual field ID

if numeric_field in df.columns:
    threshold = 10  # Example threshold 
    filtered_df = df[df[numeric_field] > threshold]
    print(f"Filtered records with {numeric_field} > {threshold}:")
    print(filtered_df.head())
    
    filtered_df[f"{numeric_field}_normalized"] = (filtered_df[numeric_field] - filtered_df[numeric_field].mean()) / filtered_df[numeric_field].std()
    print(f"Normalized {numeric_field} for filtered records:")
    print(filtered_df[[numeric_field, f"{numeric_field}_normalized"]].head())
    
    group_field = 'group_field_id'  # Example: Replace with actual group field ID
    if group_field in df.columns:
        grouped_df = filtered_df.groupby(group_field).mean()
        print(f"Grouped data by {group_field}:")
        print(grouped_df.head())

# %% [markdown]
# ## 5. Visualization
# Visualize data distributions or relationships between fields in the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of a numeric field
if numeric_field in df.columns:
    sns.histplot(df[numeric_field], bins=30, kde=True)
    plt.title(f'Distribution of {numeric_field}')
    plt.xlabel(numeric_field)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ## 6. Conclusion
# Summarize key findings and observations from the dataset exploration. This can include insights into patterns or anomalies noticed during EDA, or potential implications of the data distribution.
